# %%
import librosa
import matplotlib.pyplot as plt
import numpy as np

# %%
array, sampling_rate = librosa.load("data/trumpetSolo.ogg")
plt.figure().set_figwidth(12)
librosa.display.waveshow(array, sr=sampling_rate)

# %%
array, sampling_rate = librosa.load("tests/data/trumpetTest1MSBasic.wav")
plt.figure().set_figwidth(12)
librosa.display.waveshow(array, sr=sampling_rate)

# %%
D = librosa.stft(array)
S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)

plt.figure().set_figwidth(12)
librosa.display.specshow(S_db, x_axis="time", y_axis="hz")
plt.colorbar()

# %%
S = librosa.feature.melspectrogram(y=array, sr=sampling_rate, n_mels=128, fmax=8000)
S_dB = librosa.power_to_db(S, ref=np.max)

plt.figure().set_figwidth(12)
librosa.display.specshow(S_dB, x_axis="time", y_axis="mel", sr=sampling_rate, fmax=8000)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 S = librosa.feature.melspectrogram(y=array, sr=sampling_rate, n_mels=128, fmax=8000)
#       2 S_dB = librosa.power_to_db(S, ref=np.max)
#       4 plt.figure().set_figwidth(12)
#
# NameError: name 'librosa' is not defined
